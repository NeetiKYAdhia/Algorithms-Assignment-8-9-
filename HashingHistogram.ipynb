2, 7, 6, 4, 4, 3, 2, 2, 2, 1, 4, 2, 1, 4, 2, 3, 3, 0, 3, 1, 2, 3, 1, 2, 2, 3, 1, 2, 1, 1, 2, 3, 2, 1, 3, 5, 2, 1, 3, 1, 4, 0, 1, 4, 2, 0, 3, 4, 3, 4, 7, 4, 4, 3, 2, 2, 1, 2, 3, 2, 6, 1, 2, 2, 2, 3, 4, 0, 2, 2, 3, 2, 3, 1, 3, 5, 1, 2, 2, 1, 4, 3, 2, 2, 5, 4, 1, 3, 3, 1, 1, 6, 3, 1, 2, 1, 2, 1, 1, 3, 1, 0, 3, 1, 2, 3, 3, 1, 4, 1, 1, 4, 0, 0, 3, 2, 4, 1, 4, 2, 2, 2, 1, 1, 2, 2, 4, 6, 1, 10, 3, 1, 2, 0, 2, 2, 2, 1, 5, 7, 5, 2, 2, 2, 2, 4, 2, 1, 4, 6, 2, 1, 2, 1, 3, 5, 4, 2, 0, 5, 4, 3, 4, 3, 3, 3, 3, 3, 6, 2, 2, 1, 1, 2, 1, 1, 5, 3, 4, 5, 1, 2, 2, 0, 1, 1, 0, 1, 0, 1, 3, 2, 1, 4, 3, 2, 4, 4, 3, 6, 2, 3, 4, 2, 2, 1, 3, 0, 2, 3, 0, 3, 2, 2, 6, 2, 2, 4, 3, 3, 5, 0, 0, 2, 3, 1, 4, 2, 1, 3, 4, 1, 4, 3, 2, 3, 2, 1, 5, 1, 3, 2, 2, 2, 2, 2, 5, 3, 3, 2, 0, 0, 3, 4, 2, 1, 1, 2, 1, 1, 1, 2, 2, 0, 2, 0, 2, 4, 5, 0, 2, 5, 0, 4, 0, 3, 4, 0, 1, 0, 3, 1, 1, 2, 2, 0, 0, 3, 1, 1, 1, 1, 2, 3, 0, 1, 1, 0, 2, 2, 3, 4, 1, 3, 0, 0, 2, 0, 1, 2, 2, 3, 2, 2, 2, 0, 5, 2, 0, 0, 4, 0, 1, 2, 4, 2, 1, 1, 3, 1, 1, 3, 0, 2, 0, 1, 1, 0, 0, 1, 2, 1, 1, 1, 2, 2, 1, 1, 2, 2, 2, 1, 0, 2, 2, 1, 1, 2, 2, 0, 0, 0, 0, 0, 1, 3, 1, 1, 0, 0, 0, 0, 2, 1, 1, 0, 2, 2, 1, 4, 1, 0, 3, 1, 0, 0, 0, 2, 3, 1, 1, 0, 0, 2, 0, 2, 1, 2, 3, 1, 2, 3, 0, 1, 0, 1, 0, 0, 1, 2, 1, 1, 0, 0, 0, 1, 0, 2, 1, 2, 2, 1]

# Display the histogram
plt.hist(collision_list_lengths1, bins=range(max(collision_list_lengths1) + 2), align='left', rwidth=0.8, color='blue', edgecolor='black')
plt.xlabel('Collision List Length')
plt.ylabel('Frequency')
plt.title('Histogram of Collision List Lengths')
plt.show()



variance = np.var(collision_list_lengths1)

# Display the result
print(f"Variance: {variance}")
# Out:
# Variance: 3.022256

# %%
import matplotlib.pyplot as plt

# Replace this with the output from your Java program
collision_list_lengths_2 = [65, 73, 80, 70, 69, 62, 79, 65, 75, 75, 53, 77, 72, 82, 61, 70, 55, 75, 83, 59, 61, 75, 81, 68, 60, 61, 66, 78, 72, 66]

# Display the histogram
plt.hist(collision_list_lengths_2, bins=range(max(collision_list_lengths_2) + 2), align='left', rwidth=0.8, color='blue', edgecolor='black')
plt.xlabel('Collision List Length')
plt.ylabel('Frequency')
plt.title('Histogram of Collision List Lengths')
plt.show()




variance = np.var(collision_list_lengths_2)

# Display the result
print(f"Variance: {variance}")
# Out:
# Variance: 65.64

# %%
import matplotlib.pyplot as plt

# Replace this with the output from your Java program
collision_list_lengths_3 = [4, 6, 10, 8, 4, 7, 7, 8, 4, 6, 4, 6, 5, 8, 8, 5, 4, 10, 8, 10, 7, 9, 10, 4, 6, 9, 5, 9, 9, 9, 4, 6, 11, 9, 6, 9, 9, 5, 6, 5, 5, 4, 6, 9, 4, 6, 7, 6, 4, 2, 4, 7, 8, 11, 7, 6, 11, 10, 7, 7, 10, 6, 8, 4, 5, 10, 8, 6, 3, 8, 7, 7, 7, 5, 3, 6, 6, 6, 6, 5, 6, 7, 3, 6, 2, 2, 4, 9, 5, 6, 6, 6, 8, 13, 10, 3, 7, 9, 8, 6, 5, 7, 8, 7, 9, 10, 4, 9, 8, 3, 5, 8, 6, 5, 6, 4, 9, 8, 10, 8, 6, 8, 3, 7, 6, 4, 8, 8, 10, 12, 8, 8, 6, 6, 6, 8, 5, 11, 13, 7, 12, 5, 11, 10, 7, 6, 8, 8, 6, 6, 5, 11, 7, 6, 8, 5, 7, 5, 10, 5, 5, 8, 6, 9, 2, 7, 6, 5, 8, 5, 3, 7, 10, 8, 6, 9, 9, 8, 7, 6, 7, 7, 4, 3, 9, 7, 10, 7, 6, 7, 4, 11, 9, 8, 7, 11, 9, 8, 8, 8, 6, 6, 8, 3, 5, 6, 6, 8, 9, 9, 11, 6, 12, 5, 6, 4, 11, 6, 6, 4, 5, 10, 6, 8, 13, 8, 6, 7, 7, 6, 8, 10, 8, 11, 10, 6, 3, 7, 4, 8, 5, 8, 10, 4, 14, 7, 7, 2, 8, 11, 2, 5, 6, 11, 8, 4, 2, 8, 13, 7, 6, 9, 8, 6, 3, 7, 4, 6, 4, 4, 7, 9, 7, 11, 1, 6, 5, 9, 14, 11, 8, 11, 13, 11, 1, 5, 6, 5, 8, 6, 4, 7, 9, 4, 8, 6, 7, 5, 11, 3]

# Display the histogram
plt.hist(collision_list_lengths_3, bins=range(max(collision_list_lengths_3) + 2), align='left', rwidth=0.8, color='blue', edgecolor='black')
plt.xlabel('Collision List Length')
plt.ylabel('Frequency')
plt.title('Histogram of Collision List Lengths')
plt.show()



variance = np.var(collision_list_lengths_3)

# Display the result
print(f"Variance: {variance}")
# Out:
# Variance: 6.125066666666666
